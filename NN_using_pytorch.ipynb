# %% [markdown]
# <a href="https://colab.research.google.com/github/PiyushiAnand/FinSearch_RL/blob/main/NN_using_pytorch.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#importing libraries
import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim

# %%
#loading dataset
dataset=np.loadtxt('ex.csv',delimiter=',')
x=dataset[:,0:8]
y=dataset[:,8]

# %%
#make tensors from numpy arrays
x=torch.tensor(x,dtype=torch.float32)
y=torch.tensor(y,dtype=torch.float32).reshape(-1,1)

# %%
#creating nn model using class
class classifier(nn.Module):
  def __init__(self):
    super().__init__()
    self.hidden1=nn.Linear(8,12)
    self.act1=nn.ReLU()
    self.hidden2=nn.Linear(12,8)
    self.act2=nn.ReLU()
    self.output=nn.Linear(8,1)
    self.act_output=nn.Sigmoid()
  #forward propogation function
  def forward(self,x):
    x=self.act1(self.hidden1(x))
    x=self.act2(self.hidden2(x))
    x=self.act_output(self.output(x))
    return x

# %%
model = classifier()
#train the model
loss=nn.MSELoss()
optimizer=optim.Adam(model.parameters(),lr=0.001)
tot_epochs=1000
batch_size=100
for epoch in range(tot_epochs):
  for i in range(0,len(x),batch_size):
    xbatch=x[i:i+batch_size]
    y_pred=model(xbatch)
    ybatch=y[i:i+batch_size]
    cost=loss(y_pred,ybatch)
    optimizer.zero_grad()
    cost.backward()
    optimizer.step()
  #print accuracy
  y_pred=model(x)
  accuracy=(y_pred.round()==y).float().mean()
  print(f"At epoch {epoch} loss = {cost} Accuracy = {accuracy*100}")
# Out:
# At epoch 0 loss = 0.602940559387207 Accuracy = 34.895835876464844
# At epoch 1 loss = 0.6029390096664429 Accuracy = 34.895835876464844
# At epoch 2 loss = 0.602932333946228 Accuracy = 34.895835876464844
# At epoch 3 loss = 0.6028978228569031 Accuracy = 34.895835876464844
# At epoch 4 loss = 0.6026632785797119 Accuracy = 34.895835876464844
# At epoch 5 loss = 0.600252091884613 Accuracy = 34.895835876464844
# At epoch 6 loss = 0.5701484084129333 Accuracy = 34.765625
# At epoch 7 loss = 0.4608243405818939 Accuracy = 42.317710876464844
# At epoch 8 loss = 0.48367220163345337 Accuracy = 49.869789123535156
# At epoch 9 loss = 0.47376805543899536 Accuracy = 55.59895706176758
# At epoch 10 loss = 0.4464997947216034 Accuracy = 59.50520706176758
# At epoch 11 loss = 0.4074416160583496 Accuracy = 62.109375
# At epoch 12 loss = 0.3842911720275879 Accuracy = 62.5
# At epoch 13 loss = 0.36985570192337036 Accuracy = 64.0625
# At epoch 14 loss = 0.3601436913013458 Accuracy = 65.10417175292969
# ...
